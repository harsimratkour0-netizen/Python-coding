# %% [markdown]
# <a href="https://colab.research.google.com/github/harsimratkour0-netizen/Python-coding/blob/main/Day11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
b=20

# %%
print(a+b)
# Out:
# 30
